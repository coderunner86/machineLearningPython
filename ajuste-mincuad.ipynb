# %%
import numpy as np
import pylab as pl

from sklearn import linear_model
#este es nuestro conjunto de prueba,es solo una linea recta con algunruido gaussiano 
xmin, xmax = -5,5
n_samples = 100
X = [[i] for i in np.linspace(xmin,xmax, n_samples)]
Y = 2 + 0.5*np.linspace(xmin,xmax,n_samples)\
+ np.random.randn(n_samples,1).ravel()

#ejecuta el clasificador
clf = linear_model.LinearRegression()
clf.fit(X,Y)
#PLOTEA
pl.scatter(X,Y, color = 'black')
pl.plot(X,clf.predict(X),color='blue',linewidth =3)
pl.xticks(())
pl.yticks(())
pl.show()
